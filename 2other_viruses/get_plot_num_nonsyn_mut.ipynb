# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
allmut = pd.read_csv('./data/allmut_nemu.csv')

# %%
allmut.head()
# Out:
#        Mut  Label  PosInGene  PosInCodon RefCodon AltCodon RefAa AltAa  \
# 0  A[G>A]A      0         29           2      AGA      AAA     R     K
# 1  G[A>C]G      1        724           1      AGG      CGG     R     R
# 2  G[C>T]C      0        773           2      GCC      GTC     A     V
# 3  A[G>A]C      0        776           2      AGC      AAC     S     N
# 4  C[A>G]C      0        797           2      CAC      CGC     H     R
#
#    ProbaRef  ProbaMut  ProbaFull RefNode AltNode  Gene  taxid Type  \
# 0  0.316040  0.301881   0.301881   Node1   Node2     1  10407   ds
# 1  0.515888  0.347033   0.347033   Node1   Node2     1  10407   ds
# 2  0.645726  0.321229   0.321229   Node1   Node2     1  10407   ds
# 3  0.657652  0.314946   0.314946   Node1   Node2     1  10407   ds
# 4  0.574844  0.342262   0.342262   Node1   Node2     1  10407   ds
#
#              taxname    df virusname  mut
# 0  Hepatitis B virus  nemu       HBV  G>A
# 1  Hepatitis B virus  nemu       HBV  A>C
# 2  Hepatitis B virus  nemu       HBV  C>T
# 3  Hepatitis B virus  nemu       HBV  G>A
# 4  Hepatitis B virus  nemu       HBV  A>G

# %%
allmut['mut'] = allmut['Mut'].str.split('[', expand=True)[1].str.split(']', expand=True)[0]

# %%
allmut
# Out:
#             Mut  Label  PosInGene  PosInCodon RefCodon AltCodon RefAa AltAa  \
# 0       A[G>A]A      0         29           2      AGA      AAA     R     K
# 1       G[A>C]G      1        724           1      AGG      CGG     R     R
# 2       G[C>T]C      0        773           2      GCC      GTC     A     V
# 3       A[G>A]C      0        776           2      AGC      AAC     S     N
# 4       C[A>G]C      0        797           2      CAC      CGC     H     R
# ...         ...    ...        ...         ...      ...      ...   ...   ...
# 594247  T[C>T]G      1       1542           3      ATC      ATT     I     I
# 594248  A[G>A]T      1       1884           3      CAG      CAA     Q     Q
# 594249  T[G>A]A      2       2010           3      GTG      GTA     V     V
# 594250  G[T>C]C      0       2531           2      GTC      GCC     V     A
# 594251  C[G>A]C      2       2943           3      ACG      ACA     T     T
#
#         ProbaRef  ProbaMut  ProbaFull RefNode AltNode  Gene  taxid Type  \
# 0       0.316040  0.301881   0.301881   Node1   Node2     1  10407   ds
# 1       0.515888  0.347033   0.347033   Node1   Node2     1  10407   ds
# 2       0.645726  0.321229   0.321229   Node1   Node2     1  10407   ds
# 3       0.657652  0.314946   0.314946   Node1   Node2     1  10407   ds
# 4       0.574844  0.342262   0.342262   Node1   Node2     1  10407   ds
# ...          ...       ...        ...     ...     ...   ...    ...  ...
# 594247  0.998150  0.998150   0.998150  Node11    RN_9     1  77763   ds
# 594248  0.999200  0.999200   0.999200  Node11    RN_9     1  77763   ds
# 594249  0.997920  0.997920   0.997920  Node11    RN_9     1  77763   ds
# 594250  0.998920  0.998920   0.998920  Node11    RN_9     1  77763   ds
# 594251  0.998060  0.998060   0.998060  Node11    RN_9     1  77763   ds
#
#                   taxname    df virusname  mut
# 0       Hepatitis B virus  nemu       HBV  G>A
# 1       Hepatitis B virus  nemu       HBV  A>C
# 2       Hepatitis B virus  nemu       HBV  C>T
# 3       Hepatitis B virus  nemu       HBV  G>A
# 4       Hepatitis B virus  nemu       HBV  A>G
# ...                   ...   ...       ...  ...
# 594247        Banna virus  nemu       BAV  C>T
# 594248        Banna virus  nemu       BAV  G>A
# 594249        Banna virus  nemu       BAV  G>A
# 594250        Banna virus  nemu       BAV  T>C
# 594251        Banna virus  nemu       BAV  G>A
#
# [594252 rows x 20 columns]

# %%
# nonsyn mutations on label 0
# allmut[allmut['Label'] == 0]

# %%
nonsynmut_count = allmut[allmut['Label'] == 0]\
                    .groupby(['Type', 'virusname']) \
                    .agg({'Mut':'count'}) \
                    .reset_index() \
                    .rename(columns={'Mut':'nonsyn_count'})
nonsynmut_count
# Out:
#    Type virusname  nonsyn_count
# 0     +     ACoV           8300
# 1     +       CTV          2281
# 2     +       DWV          1758
# 3     +      FMDV          2976
# 4     +       HAV          1171
# 5     +       HCV          6189
# 6     +       HEV          5956
# 7     +       HGV          1945
# 8     +      PEDV          1470
# 9     +     PRRSV          4961
# 10    +       WNV           502
# 11    +    alCoV1          1044
# 12    +      denv           975
# 13    +       evA          2911
# 14    +       evC          4999
# 15    +       evD          2301
# 16    +      norw           828
# 17    -     EBLV1           156
# 18    -       HMV          1106
# 19    -      OROV           485
# 20    -      PUUV           681
# 21    -       RSV           340
# 22    -       SBV           757
# 23    -       aka           428
# 24   ds       BAV           354
# 25   ds      EHDV           458
# 26   ds       HBV          3094
# 27   ds       MRV           690
# 28   ds       PRV            97
# 29   ds     RBSDV           341
# 30   ds      aorv           458

# %%
fig, ax = plt.subplots()
g = sns.barplot(data=nonsynmut_count, x='virusname', y='nonsyn_count', hue='Type')

ax.tick_params(axis='x', rotation=90)

ax.set_xlabel('Viruses')
ax.set_ylabel('Count')
ax.set_title('Number of nonsynonymous mutation in viruses')

# fig.tight_layout()
# Out:
# Text(0.5, 1.0, 'Number of nonsynonymous mutation in viruses')

# %%
sns.catplot(data=nonsynmut_count, x='mut', y='count', hue='virusname', col='Type')

# %%
mutation_count = nonsynmut_count.merge(allmut[allmut['Label'] > 0] \
                                                   .groupby(['Type', 'virusname']) \
                                                   .agg({'mut':'count'}) \
                                                   .reset_index() \
                                                   .rename(columns={'mut':'syn_count'}))
mutation_count['dN/dS'] = mutation_count['nonsyn_count']/mutation_count['syn_count']
mutation_count
# Out:
#    Type virusname  nonsyn_count  syn_count     dN/dS
# 0     +     ACoV           8300      52229  0.158916
# 1     +       CTV          2281       5747  0.396903
# 2     +       DWV          1758      14711  0.119502
# 3     +      FMDV          2976      16632  0.178932
# 4     +       HAV          1171      17460  0.067068
# 5     +       HCV          6189      27267  0.226978
# 6     +       HEV          5956      93125  0.063957
# 7     +       HGV          1945      51733  0.037597
# 8     +      PEDV          1470       5273  0.278779
# 9     +     PRRSV          4961       8695  0.570558
# 10    +       WNV           502       2348  0.213799
# 11    +    alCoV1          1044       3234  0.322820
# 12    +      denv           975       4977  0.195901
# 13    +       evA          2911      39710  0.073306
# 14    +       evC          4999      73274  0.068223
# 15    +       evD          2301      17661  0.130287
# 16    +      norw           828      14678  0.056411
# 17    -     EBLV1           156       1741  0.089604
# 18    -       HMV          1106       7989  0.138440
# 19    -      OROV           485       4940  0.098178
# 20    -      PUUV           681      19004  0.035835
# 21    -       RSV           340       3250  0.104615
# 22    -       SBV           757        295  2.566102
# 23    -       aka           428       4194  0.102051
# 24   ds       BAV           354       3818  0.092719
# 25   ds      EHDV           458       4689  0.097675
# 26   ds       HBV          3094       4216  0.733871
# 27   ds       MRV           690      12967  0.053212
# 28   ds       PRV            97       1539  0.063028
# 29   ds     RBSDV           341       1862  0.183136
# 30   ds      aorv           458      14981  0.030572

# %%
fig, ax = plt.subplots()
g = sns.barplot(data=mutation_count, x='virusname', y='dN/dS', hue='Type')

ax.tick_params(axis='x', rotation=90)

ax.set_xlabel('Viruses')
ax.set_ylabel('dN/dS')
ax.set_title('dN/dS ratio in viruses')
# Out:
# Text(0.5, 1.0, 'dN/dS ratio in viruses')
