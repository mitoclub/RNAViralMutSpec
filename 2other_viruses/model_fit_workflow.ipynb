# 23                                  Avian coronavirus  nemu   694014     ACoV
# 24                      Schmallenberg orthobunyavirus  nemu  1133363       SBV
# 25                              Piscine orthoreovirus  nemu  1157337       PRV
# 26                                   Orthohepevirus A  nemu  1678143       HEV
# 27                            Akabane orthobunyavirus  nemu  1933178       aka
# 28                                Hepacivirus hominis  nemu  3052230       HCV
# 29                            Puumala orthohantavirus  nemu  3052493      PUUV
# 30                             Rice stripe tenuivirus  nemu  3052763       RSV

# %%
mut_all = pd.read_csv('./data/allmut_nemu.csv')
mut_ns = mut_all[mut_all['Label'] == 0]
mut_ns
# Out:
#             Mut  Label  PosInGene  PosInCodon RefCodon AltCodon RefAa AltAa  \
# 0       A[G>A]A      0         29           2      AGA      AAA     R     K
# 2       G[C>T]C      0        773           2      GCC      GTC     A     V
# 3       A[G>A]C      0        776           2      AGC      AAC     S     N
# 4       C[A>G]C      0        797           2      CAC      CGC     H     R
# 5       A[G>A]G      0        904           1      GGA      AGA     G     R
# ...         ...    ...        ...         ...      ...      ...   ...   ...
# 594233  A[A>T]T      0        812           2      AAT      ATT     N     I
# 594235  C[A>G]C      0       1391           2      CAC      CGC     H     R
# 594244  A[G>A]C      0         68           2      AGC      AAC     S     N
# 594246  G[G>T]C      0       1153           1      GCT      TCT     A     S
# 594250  G[T>C]C      0       2531           2      GTC      GCC     V     A
#
#         ProbaRef  ProbaMut  ProbaFull RefNode AltNode  Gene  taxid Type  \
# 0       0.316040  0.301881   0.301881   Node1   Node2     1  10407   ds
# 2       0.645726  0.321229   0.321229   Node1   Node2     1  10407   ds
# 3       0.657652  0.314946   0.314946   Node1   Node2     1  10407   ds
# 4       0.574844  0.342262   0.342262   Node1   Node2     1  10407   ds
# 5       0.736543  0.713864   0.713864   Node1   Node2     1  10407   ds
# ...          ...       ...        ...     ...     ...   ...    ...  ...
# 594233  0.997930  0.997930   0.997930   Node2    RN_3     1  77763   ds
# 594235  0.987528  0.987528   0.987528   Node2    RN_3     1  77763   ds
# 594244  0.999620  0.999620   0.999620  Node11    RN_9     1  77763   ds
# 594246  0.999950  0.999950   0.999950  Node11    RN_9     1  77763   ds
# 594250  0.998920  0.998920   0.998920  Node11    RN_9     1  77763   ds
#
#                   taxname    df virusname
# 0       Hepatitis B virus  nemu       HBV
# 2       Hepatitis B virus  nemu       HBV
# 3       Hepatitis B virus  nemu       HBV
# 4       Hepatitis B virus  nemu       HBV
# 5       Hepatitis B virus  nemu       HBV
# ...                   ...   ...       ...
# 594233        Banna virus  nemu       BAV
# 594235        Banna virus  nemu       BAV
# 594244        Banna virus  nemu       BAV
# 594246        Banna virus  nemu       BAV
# 594250        Banna virus  nemu       BAV
#
# [60012 rows x 19 columns]

# %%
from pymutspec.annotation import mutations_summary

_ = mutations_summary(mut_all, 'taxname')
_.to_csv('./data/mutation_summary_vir.csv')  # Supl Table 1
_
# Out:
#                                                     non-syn      syn    syn4f  \
# taxname
# Akabane orthobunyavirus                               428.0   4194.0   1495.0
# Alphacoronavirus 1                                   1044.0   3234.0   1507.0
# Avian coronavirus                                    8300.0  52229.0  24712.0
# Avian orthoreovirus                                   458.0  14981.0   8748.0
# Banna virus                                           354.0   3818.0   1717.0
# Citrus tristeza virus                                2281.0   5747.0   2959.0
# Deformed wing virus                                  1758.0  14711.0   6977.0
# Dengue virus                                          975.0   4977.0   2423.0
# Enterovirus A                                        2911.0  39710.0  19074.0
# Enterovirus C                                        4999.0  73274.0  34515.0
# Enterovirus D                                        2301.0  17661.0   7713.0
# Epizootic hemorrhagic disease virus                   458.0   4689.0   2010.0
# European bat 1 lyssavirus                             156.0   1741.0    832.0
# Foot-and-mouth disease virus                         2976.0  16632.0   8388.0
# GB virus C                                           1945.0  51733.0  35026.0
# Hepacivirus hominis                                  6189.0  27267.0  16280.0
# Hepatitis B virus                                    3094.0   4216.0   2245.0
# Hepatovirus A                                        1171.0  17460.0   7179.0
# Human metapneumovirus                                1106.0   7989.0   2895.0
# Mammalian orthoreovirus                               690.0  12967.0   6505.0
# Norwalk virus                                         828.0  14678.0   7623.0
# Oropouche orthobunyavirus                             485.0   4940.0   1764.0
# Orthohepevirus A                                     5956.0  93125.0  54142.0
# Piscine orthoreovirus                                  97.0   1539.0    846.0
# Porcine epidemic diarrhea virus                      1470.0   5273.0   2437.0
# Porcine reproductive and respiratory syndrome v...   4961.0   8695.0   4968.0
# Puumala orthohantavirus                               681.0  19004.0   7286.0
# Rice black streaked dwarf virus                       341.0   1862.0    699.0
# Rice stripe tenuivirus                                340.0   3250.0   1436.0
# Schmallenberg orthobunyavirus                         757.0    295.0    121.0
# West Nile virus                                       502.0   2348.0   1079.0
#
#                                                     Stop loss
# taxname
# Akabane orthobunyavirus                                   0.0
# Alphacoronavirus 1                                        0.0
# Avian coronavirus                                         0.0
# Avian orthoreovirus                                       0.0
# Banna virus                                               0.0
# Citrus tristeza virus                                     0.0
# Deformed wing virus                                       0.0
# Dengue virus                                              0.0
# Enterovirus A                                             0.0
# Enterovirus C                                             0.0
# Enterovirus D                                             0.0
# Epizootic hemorrhagic disease virus                       0.0
# European bat 1 lyssavirus                                 0.0
# Foot-and-mouth disease virus                              0.0
# GB virus C                                                0.0
# Hepacivirus hominis                                       0.0
# Hepatitis B virus                                         0.0
# Hepatovirus A                                             0.0
# Human metapneumovirus                                     0.0
# Mammalian orthoreovirus                                   0.0
# Norwalk virus                                             0.0
# Oropouche orthobunyavirus                                 0.0
# Orthohepevirus A                                          1.0
# Piscine orthoreovirus                                     0.0
# Porcine epidemic diarrhea virus                           0.0
# Porcine reproductive and respiratory syndrome v...        0.0
# Puumala orthohantavirus                                   0.0
# Rice black streaked dwarf virus                           0.0
# Rice stripe tenuivirus                                    0.0
# Schmallenberg orthobunyavirus                             0.0
# West Nile virus                                           0.0

# %%
_d = mut_ns.groupby(['Type', 'virusname']).ProbaFull.sum().sort_values(ascending=False)
plt.figure(figsize=(10, 4))
_d.plot.bar(color=_d.index.get_level_values(0).map({'+': 'green', 'ds': 'orange', '-': 'blue'}))

plt.hlines(y=2000, xmin=-1, xmax=mut_all['virusname'].nunique(), color='red', linestyle='--')
plt.ylabel('Number of non-synonymous mutations')
plt.yscale('log')
legend_labels = {'green': 'ssRNA(+)', 'orange': 'dsRNA', 'blue': 'ssRNA(-)', 'red': '2000 mutations'}
patches = [mpatches.Patch(color=color, label=label) for color, label in legend_labels.items()]
plt.legend(handles=patches, loc="upper right")
# plt.savefig('figures/ns_mut_cnt.pdf', bbox_inches='tight')
plt.show()

# %%
dnds = mut_all.groupby(['Type', 'virusname', 'Label']).ProbaFull.sum().unstack()
dnds['Dn'] = dnds[0]
dnds['Ds'] = dnds[1] + dnds[2]
dnds['DnDs'] = dnds['Dn'] / (dnds['Dn'] + dnds['Ds'])

_d = dnds.DnDs.sort_values(ascending=False)


plt.figure(figsize=(10, 4))
ax = _d.plot.bar(color=_d.index.get_level_values(0).map({'+': 'green', 'ds': 'orange', '-': 'blue'}))
plt.hlines(y=_d.median(), xmin=-1, xmax=_d.index.nunique(), color='red', linestyle='--', label='median')
legend_labels = {'green': 'ssRNA(+)', 'orange': 'dsRNA', 'blue': 'ssRNA(-)', 'red': 'median'}
patches = [mpatches.Patch(color=color, label=label) for color, label in legend_labels.items()]
plt.legend(handles=patches, loc="upper right")
plt.grid(axis='y', color='.85')
ax.set_axisbelow(True)
plt.ylabel('Fraction of non-synonymous mutations')
# plt.savefig('figures/ns_mut_frac.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
ts = spectra['C>T'] + spectra['T>C'] + spectra['A>G'] + spectra['G>A']
tv = spectra.iloc[:, :12].sum(1) - ts
spectra['ts_tv'] = ts / tv

_d = spectra.set_index(['Type', 'virusname', ]).ts_tv.sort_values(ascending=False)

plt.figure(figsize=(10, 4))
ax = _d.plot.bar(color=_d.index.get_level_values(0).map({'+': 'green', 'ds': 'orange', '-': 'blue'}))
# plt.hlines(y=_d.median(), xmin=-1, xmax=_d.index.nunique(), color='red', linestyle='--', label='median')
legend_labels = {'green': 'ssRNA(+)', 'orange': 'dsRNA', 'blue': 'ssRNA(-)',}
patches = [mpatches.Patch(color=color, label=label) for color, label in legend_labels.items()]
plt.legend(handles=patches, loc="upper right")
plt.grid(axis='y', color='.85')
ax.set_axisbelow(True)
plt.ylabel('Ts/Tv ratio')
# plt.savefig('figures/tstv.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Neutral model fit results

# %%
vir_fit = pd.read_csv('./data/virs_fit_metrics.csv')\
    .sort_values(['Type', 'mut_count']).set_index(['Type', 'virusname'])
print(vir_fit.shape)
vir_fit
# Out:
# (20, 14)
#                       r2     mape      wape     slope  intercept  \
# Type virusname
# +    WNV        0.033837  1.71924  0.843942  0.371521   0.004190
#      norw       0.047302  3.54595  0.922882  0.252156   0.004986
#      alCoV1    -0.302937  1.41201  0.754293  0.359105   0.004273
#      denv       0.134120  2.01187  0.782598  0.355615   0.004296
#      HAV       -0.846721  1.83527  1.029350  0.273920   0.004841
#      PEDV      -0.049517  1.17231  0.784659  0.515342   0.003231
#      evA        0.200000  4.857930e-03  0.012469        -5.53587   2801.190
#      FMDV       0.200000  4.857930e-03  0.009674        -5.59910   2802.690
#      PRRSV      0.146667  7.930980e-02  0.005265        -5.61376   4482.460
#      evC        0.273333  2.445510e-05  0.010163        -5.64062   4620.750
#      HEV        0.093333  5.321870e-01  0.007846        -5.56668   4869.510
#      HCV        0.293333  4.284920e-06  0.012426        -5.79847   5532.530
#      ACoV       0.206667  3.220730e-03  0.009181        -5.81193   7281.830
# -    HMV        0.213333  2.105860e-03  0.010271        -5.70834   1063.280
# ds   MRV        0.386667  2.176880e-10  0.012384        -5.71456    576.372
#      HBV        0.233333  5.413960e-04  0.006936        -5.87548   2874.590

# %%
vir_fit[['spearman_corr', 'r2', 'slope', 'mut_count']]\
    .reset_index().drop('virusname', axis=1).groupby('Type').mean().round(2)
# Out:
#       spearman_corr    r2  slope  mut_count
# Type
# +              0.60  0.06   0.39    2660.63
# -              0.63  0.16   0.43    1063.28
# ds             0.57  0.12   0.26    1725.48

# %% [markdown]
# ## Random model fit results

# %%
metrics_rnd_df = pd.read_csv('data/virs_rnd_fit_metrics.csv', index_col=[0,1,2,3])
print(metrics_rnd_df.shape)
# Out:
# (441, 14)

# %%
_ = metrics_rnd_df[['spearman_corr', 'r2', 'slope', 'wape']]\
    .melt(ignore_index=False, var_name='metric').reset_index()
g = sns.catplot(data=_, sharey=False, kind='box', col='metric', col_wrap=2,
                y='value', hue='model', x='Type', palette='Set2', height=2.5, aspect=1.3,
)
g.set_titles('{col_name}')
# g.set_xticklabels(g.axes[2].get_xticklabels(), rotation=-45)
g.set_xlabels('RNA Sense')
g.set_ylabels('Metric value')
g.savefig('./figures/vir_rnd_fit_metrics_boxplots.pdf')

# %%
# correlations significance
metrics_rnd_df[['spearman_p', 'pearson_p']]\
    .melt(ignore_index=False, var_name='metric').reset_index()\
        .groupby(['model',  'metric']).value.agg(['mean', 'std', 'max']).round(5)
# Out:
#                        mean      std      max
# model   metric
# neutral pearson_p   0.00021  0.00094  0.00429
#         spearman_p  0.00000  0.00001  0.00003
# random  pearson_p   0.29072  0.30383  0.99722
#         spearman_p  0.15014  0.24622  0.99511

# %%
# correlations significance
metrics_rnd_df[['spearman_p', 'pearson_p']]\
    .melt(ignore_index=False, var_name='metric').reset_index()\
        .groupby(['model', 'Type',  'metric']).value.agg(['mean', 'std', 'max']).round(5)
# Out:
#                             mean      std      max
# model   Type metric
# neutral +    pearson_p   0.00026  0.00104  0.00429
#              spearman_p  0.00000  0.00001  0.00003
#         -    pearson_p   0.00000  0.00000  0.00000
#              spearman_p  0.00000  0.00000  0.00000
#         ds   pearson_p   0.00000  0.00000  0.00000
#              spearman_p  0.00000  0.00000  0.00000
# random  +    pearson_p   0.28674  0.30563  0.99722
#              spearman_p  0.14909  0.24949  0.99511
#         -    pearson_p   0.28666  0.27757  0.91258
#              spearman_p  0.20193  0.27182  0.86726
#         ds   pearson_p   0.32868  0.31803  0.96397
#              spearman_p  0.10725  0.17811  0.72534

# %%
metrics_rnd_df.reset_index().query('Type == "-" & model == "neutral"')
# Out:
#     Type virusname    model  replica        r2     mape      wape     slope  \
# 189    -       HMV  neutral        1  0.164452  1.34446  0.802944  0.434263
# 273    -       SBV  neutral        1  0.261519  1.04424  0.694189  0.605195
#
#      intercept  spearman_corr    spearman_p  pearson_corr     pearson_p  \
# 189   0.003772       0.633503  3.328140e-18      0.517540  1.188660e-11
# 273   0.002686       0.585873  6.439950e-15      0.621286  4.623950e-17
#
#       ks_stat      ks_p      rmse  log_likelihood  mut_count
# 189  0.213333  0.002106  0.010271        -5.70834   1063.280
# 273  0.204082  0.004291  0.008393            -inf    752.477

# %%
metrics_rnd_df.reset_index().query('r2 < 0 & model == "neutral"')
# Out:
#     Type virusname    model  replica        r2     mape      wape     slope  \
# 42     +       DWV  neutral        1 -0.413318  1.48995  0.855090  0.516771
# 84     +       HAV  neutral        1 -0.846721  1.83527  1.029350  0.273920
# 231    +      PEDV  neutral        1 -0.049517  1.17231  0.784659  0.515342
# 315    +    alCoV1  neutral        1 -0.302937  1.41201  0.754293  0.359105
#
#      intercept  spearman_corr    spearman_p  pearson_corr     pearson_p  \
# 42    0.003222       0.639456  1.284920e-18      0.429621  4.106580e-08
# 84    0.004841       0.336617  2.533470e-05      0.231956  4.287970e-03
# 231   0.003231       0.508756  2.988410e-11      0.495842  1.105980e-10
# 315   0.004273       0.359444  6.261810e-06      0.355367  8.101800e-06
#
#       ks_stat      ks_p      rmse  log_likelihood  mut_count
# 42   0.200000  0.004858  0.011607        -5.87911   1568.950
# 84   0.166667  0.030839  0.013440        -6.26793   1020.310
# 231  0.120000  0.230782  0.008605        -5.98029   1458.280
# 315  0.140000  0.105738  0.008489        -6.08549    929.824

# %%
# sns.lineplot(metrics_rnd_df.reset_index(), x='virusname', y='r2')
_ = metrics_rnd_df.query('mut_count > 2000').reset_index()
_['Type'] = _['Type'].map({'+': 'ssRNA(+)', 'ds': 'dsRNA'})
_['Virus'] = _.Type + ': ' + _.virusname
g = sns.catplot(
    _, hue='Virus', y='r2', x='model', aspect=1.2, legend=False,
    kind='point', order=['random', 'neutral'], palette='tab20')
g.set_ylabels('$R^2$', fontsize=14)
g.set_xlabels('Model', fontsize=14)
plt.grid(axis='y')
plt.xlim(-0.1, 1.1)
# Out:
# (-0.1, 1.1)

# %%
# sns.lineplot(metrics_rnd_df.reset_index(), x='virusname', y='r2')
_ = metrics_rnd_df.query('mut_count > 2000').reset_index()
_['Type'] = _['Type'].map({'+': 'ssRNA(+)', 'ds': 'dsRNA'})
_['Virus'] = _.Type + ': ' + _.virusname
g = sns.catplot(
    _, hue='Virus', y='spearman_corr', x='model',aspect=1.2,
    kind='point', order=['random', 'neutral'], palette='tab20')
g.set_ylabels('Spearman R', fontsize=14)
g.set_xlabels('Model', fontsize=14)
plt.grid(axis='y')
plt.xlim(-0.1, 1.1)
# Out:
# (-0.1, 1.1)
